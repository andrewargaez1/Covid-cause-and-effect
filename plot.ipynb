# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import os
import requests  
import pyspark as ps
import re
import plotly.graph_objects as go
import plotly.express as px
from scipy import stats
from pyspark.sql.functions import udf, concat, col, lit
from numpy.core.fromnumeric import shape
from pyspark.sql.types import *
from pyspark.sql import functions as f

# %%
yourpath = './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/'

dict = {}
for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        dict[name[:-4]]= pd.read_csv(yourpath+name)

# %%
pop_density= pd.read_csv('./Population-Density_By_State.csv', delimiter=',')  
pop_density.rename(columns={'GEO.display-label':'States'}, inplace=True)
pop_density.drop(columns=['GEO.id','GEO.id2'], axis=1, inplace=True)
pop_density.drop(index=[51],axis=0, inplace=True)

# %%
dc =pd.Series({'state_name':'District of Columbia','party':'democrat','name':'Muriel Bowser'})
governor= pd.read_csv('./us-governors.csv', delimiter=',')
pop_density.rename(columns={'state_name':'States'}, inplace=True)
governor.drop(columns=['state_name_slug','state_code','state_code_slug','votesmart','title','name_slug','first_name','middle_name','last_name','name_suffix','goes_by','pronunciation','gender','ethnicity','religion','openly_lgbtq','date_of_birth','entered_office','term_end','biography','phone','fax','latitude','longitude','address_complete','address_number','address_prefix','address_street','address_sec_unit_type','address_sec_unit_num','address_city','address_state','address_zipcode','address_type','website','contact_page','facebook_url','twitter_handle','twitter_url','photo_url'], axis=1, inplace=True)
poli_leader = governor.append(dc,ignore_index=True)
poli_leader = poli_leader.sort_values(by=['state_name'])

# %%
popu= pd.read_csv('./popstate.csv', delimiter='\t')
#popu.drop(columns=['Pop_1990','Pop_2000','Pop_2010','Change2010-19'])

# %%
city_pop = pd.read_csv('./PopbyCIty.csv', engine='python', delimiter='\t')

# %%
citypop = spark.read.options(header='True', inferSchema='True', delimiter='\t').csv('./popcity.csv')
citypop.createOrReplaceTempView('cp')
commaRep = udf(lambda x: re.sub(',','', x))
test=citypop.select('2020rank',col("estimate").alias('estimate'))
test=test.withColumn('estimate',commaRep('estimate'))
test=test.withColumn("estimate",test.estimate.cast(IntegerType()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-b9a75e4fe0d5> in <module>
# ----> 1 citypop = spark.read.options(header='True', inferSchema='True', delimiter='\t').csv('./popcity.csv')
#       2 citypop.createOrReplaceTempView('cp')
#       3 commaRep = udf(lambda x: re.sub(',','', x))
#       4 test=citypop.select('2020rank',col("estimate").alias('estimate'))
#       5 test=test.withColumn('estimate',commaRep('estimate'))
#
# NameError: name 'spark' is not defined

# %%
c1 = spark.sql('SELECT State as States, COUNT(State) as Cities_100 FROM cp GROUP BY State ORDER BY State')
cit_100 = c1.toPandas()
ss =pd.DataFrame({'States':[' West Virginia',' Maine',' Vermont', ' Wyoming',' Delaware'], 'Cities_100':[0,0,0,0,0]})
cit_100 = cit_100.append(ss,ignore_index=True)
cit_100 = cit_100.sort_values(by=['States'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-ba5c20425372> in <module>
# ----> 1 c1 = spark.sql('SELECT State as States, COUNT(State) as Cities_100 FROM cp GROUP BY State ORDER BY State')
#       2 cit_100 = c1.toPandas()
#       3 ss =pd.DataFrame({'States':[' West Virginia',' Maine',' Vermont', ' Wyoming',' Delaware'], 'Cities_100':[0,0,0,0,0]})
#       4 cit_100 = cit_100.append(ss,ignore_index=True)
#       5 cit_100 = cit_100.sort_values(by=['States'])
#
# NameError: name 'spark' is not defined

# %%
cit_500= spark.sql('SELECT State, COUNT(State) as Count FROM cp WHERE estimate>500000 GROUP BY State ORDER BY State')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-99562cd1b590> in <module>
# ----> 1 cit_500= spark.sql('SELECT State, COUNT(State) as Count FROM cp WHERE estimate>500000 GROUP BY State ORDER BY State')
#
# NameError: name 'spark' is not defined

# %%
twentyone={}
twenty = {}

for k,v in dict.items():
    if k[-1]=='1':
        
        twentyone[k]=v
    else:
        twenty[k]=v

# %%
df = pd.DataFrame()
for k,v in sorted(twenty.items()):
    df['States']= v['Province_State']
    df['Lat']= v['Lat']
    df['Long']= v['Long_']
    break
df.sort_values(by='States')
df.drop(index=[2,9,13,14,39,44,52,58], inplace=True)

# %%
new_df= df.merge(pop_density['Density per square mile of land area'], on=pop_density['States'], how='left')
new_df.drop(columns='key_0', inplace=True)
new_df1= new_df.merge(poli_leader['party'], on=pop_density['States'], how='left')
new_df1.drop(columns='key_0', inplace=True)
new_df2= new_df1.merge(cit_100['Cities_100'], on=pop_density['States'], how='inner')
new_df2.drop(columns='key_0', inplace=True)
new_df3= new_df2.merge(popu['Pop_2019'], on=pop_density['States'], how='inner')
new_df3.drop(columns='key_0', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-b4bea37a45c9> in <module>
#       3 new_df1= new_df.merge(poli_leader['party'], on=pop_density['States'], how='left')
#       4 new_df1.drop(columns='key_0', inplace=True)
# ----> 5 new_df2= new_df1.merge(cit_100['Cities_100'], on=pop_density['States'], how='inner')
#       6 new_df2.drop(columns='key_0', inplace=True)
#       7 new_df3= new_df2.merge(popu['Pop_2019'], on=pop_density['States'], how='inner')
#
# NameError: name 'cit_100' is not defined

# %%
for k,v in sorted(twenty.items()):
    v.sort_values(by='Province_State')
    v.drop(index=[2,9,13,14,39,44,52], inplace=True)
    v.index=range(0,len(v))
for k,v in sorted(twentyone.items()):
    v.sort_values(by='Province_State')
    v.drop(index=[2,9,13,14,39,44,52], inplace=True)
    v.index=range(0,len(v))

# %%
for k,v in sorted(twenty.items()):
    #lst.append(v['Confirmed'])
    #lst.append(v['Deaths'])
    new_df3[k + ' confirmed'] = v['Confirmed']
    new_df3[k + ' deaths'] = v['Deaths']

for k,v in sorted(twentyone.items()):
    new_df3[k + ' confirmed'] = v['Confirmed']
    new_df3[k + ' deaths'] = v['Deaths']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-4e2d212152a8> in <module>
#       2     #lst.append(v['Confirmed'])
#       3     #lst.append(v['Deaths'])
# ----> 4     new_df3[k + ' confirmed'] = v['Confirmed']
#       5     new_df3[k + ' deaths'] = v['Deaths']
#       6
#
# NameError: name 'new_df3' is not defined

# %%
confirmed_cases=new_df3.iloc[:,7::2]
confirmed_deaths=new_df3.iloc[:,8::2]

# %%
confirmed_death_total=new_df3.iloc[:,-1]
confirmed_cases_total=new_df3.iloc[:,-2]
new_df3['cd_percentage'] = confirmed_death_total/new_df3['Pop_2019']
new_df3['cc_percentage'] = confirmed_cases_total/new_df3['Pop_2019']
new_df3
# Out:
#                   States      Lat      Long  \
# 50               Wyoming  42.7560 -107.3025
# 48         West Virginia  38.4912  -80.9545
# 45               Vermont  44.0459  -72.7107
# 19                 Maine  44.6939  -69.3819
# 7               Delaware  39.3185  -75.5071
# 26               Montana  46.9219 -110.4544
# 24           Mississippi  32.7416  -89.6787
# 20              Maryland  39.0639  -76.8021
# 34          North Dakota  47.5289  -99.7840
# 11                Hawaii  21.0943 -157.4983
# 29         New Hampshire  43.4525  -71.5639
# 8   District of Columbia  38.8974  -77.0268
# 1                 Alaska  61.3707 -152.4044
# 41          South Dakota  44.2998  -99.4388
# 39          Rhode Island  41.6809  -71.5118
# 3               Arkansas  34.9697  -92.3731
# 27              Nebraska  41.1254  -98.2681
# 17              Kentucky  37.6681  -84.6701
# 31            New Mexico  34.8405 -106.2485
# 40        South Carolina  33.8569  -80.9450
# 12                 Idaho  44.2405 -114.4788
# 38          Pennsylvania  40.5908  -77.2098
# 15                  Iowa  42.0115  -93.2105
# 49             Wisconsin  44.2685  -89.6165
# 23             Minnesota  45.6945  -93.9002
# 44                  Utah  40.1500 -111.8624
# 18             Louisiana  31.1695  -91.8678
# 30            New Jersey  40.2989  -74.5210
# 36              Oklahoma  35.5653  -96.9289
# 32              New York  42.1657  -74.9481
# 0                Alabama  32.3182  -86.9023
# 21         Massachusetts  42.2302  -71.5301
# 16                Kansas  38.5266  -96.7265
# 6            Connecticut  41.5978  -72.7554
# 14               Indiana  39.8494  -86.2583
# 28                Nevada  38.3135 -117.0554
# 22              Michigan  43.3266  -84.5361
# 42             Tennessee  35.7478  -86.6923
# 25              Missouri  38.4561  -92.2884
# 37                Oregon  44.5720 -122.0709
# 35                  Ohio  40.3888  -82.7649
# 46              Virginia  37.7693  -78.1700
# 10               Georgia  33.0406  -83.6431
# 13              Illinois  40.3495  -88.9861
# 33        North Carolina  35.6301  -79.8064
# 47            Washington  47.4009 -121.4905
# 2                Arizona  33.7298 -111.4312
# 5               Colorado  39.0598 -105.3111
# 9                Florida  27.7663  -81.6868
# 43                 Texas  31.0545  -97.5635
# 4             California  36.1162 -119.6816
#
#     Density per square mile of land area       party  Cities_100  Pop_2019  \
# 50                                   5.8  republican           0    578759
# 48                                  77.1    democrat           0   1792147
# 45                                  67.9  republican           0    623989
# 19                                  43.1    democrat           0   1344212
# 7                                  460.8    democrat           0    973764
# 26                                   6.8  republican           1   1068778
# 24                                  63.2  republican           1   2976149
# 20                                 594.8  republican           1   6045680
# 34                                   9.7  republican           1    762062
# 11                                 211.8    democrat           1   1415872
# 29                                 147.0  republican           1   1359711
# 8                                 9856.5    democrat           1    705749
# 1                                    1.2  republican           1    731545
# 41                                  10.7  republican           1    884659
# 39                                1018.1    democrat           1   1059361
# 3                                   56.0  republican           1   3017804
# 27                                  23.8  republican           2   1934408
# 17                                 109.9    democrat           2   4467673
# 31                                  17.0    democrat           2   2096829
# 40                                 153.9  republican           3   5148714
# 12                                  19.0  republican           3   1787065
# 38                                 283.9    democrat           3  12801989
# 15                                  54.5  republican           3   3155070
# 49                                 105.0    democrat           3   5822434
# 23                                  66.6    democrat           3   5639632
# 44                                  33.6  republican           4   3205958
# 18                                 104.9    democrat           4   4648794
# 30                                1195.5    democrat           4   8882190
# 36                                  54.7  republican           4   3956971
# 32                                 411.2    democrat           5  19453561
# 0                                   94.4  republican           5   4903185
# 21                                 839.4  republican           5   6892503
# 16                                  34.9    democrat           5   2913314
# 6                                  738.1    democrat           5   3565287
# 14                                 181.0  republican           5   6732219
# 28                                  24.6    democrat           5   3080156
# 22                                 174.8    democrat           6   9986857
# 42                                 153.9  republican           6   6829174
# 25                                  87.1  republican           6   6137428
# 37                                  39.9    democrat           6   4217737
# 35                                 282.3  republican           6  11689100
# 46                                 202.6    democrat           7   8535519
# 10                                 168.4  republican           8  10617423
# 13                                 231.1    democrat           8  12671821
# 33                                 196.1    democrat           9  10488084
# 47                                 101.2    democrat           9   7614893
# 2                                   56.3  republican          10   7278717
# 5                                   48.5    democrat          12   5758736
# 9                                  350.6  republican          22  21477737
# 43                                  96.3  republican          41  28995881
# 4                                  239.1    democrat          75  39512223
#
#     04-13-2020 confirmed  04-13-2020 deaths  04-14-2020 confirmed  ...  \
# 50                   275                  1                   282  ...
# 48                   611                  8                   640  ...
# 45                   748                 28                   752  ...
# 19                   698                 19                   735  ...
# 7                   1758                 54                  1926  ...
# 26                   394                  7                   399  ...
# 24                  2942                 98                  3087  ...
# 20                  8936                262                  9472  ...
# 34                   331                  8                   341  ...
# 11                   504                  9                   511  ...
# 29                   985                 23                   922  ...
# 8                   1955                 52                  2058  ...
# 1                    277                  8                   285  ...
# 41                   868                  6                   988  ...
# 39                  2665                100                  3251  ...
# 3                   1410                 29                  1498  ...
# 27                   814                 17                   897  ...
# 17                  2018                113                  2048  ...
# 31                  1262                 26                  1345  ...
# 40                  3391                 82                  3553  ...
# 12                  1426                 27                  1464  ...
# 38                 24336                610                 25502  ...
# 15                  1710                 41                  1899  ...
# 49                  3428                154                  3555  ...
# 23                  1621                 70                  1695  ...
# 44                  2363                 13                  2417  ...
# 18                 21016                884                 21518  ...
# 30                 64584               2443                 68824  ...
# 36                  2069                 99                  2184  ...
# 32                195749              10058                203020  ...
# 0                   3870                 99                  4041  ...
# 21                 26867                844                 28164  ...
# 16                  1390                 61                  1441  ...
# 6                  13381                602                 13989  ...
# 14                  8359                483                  8527  ...
# 28                  2990                114                  3134  ...
# 22                 25635               1602                 27001  ...
# 42                  5610                109                  5827  ...
# 25                  4568                128                  4815  ...
# 37                  1584                 53                  1633  ...
# 35                  6975                399                  7285  ...
# 46                  5747                149                  6182  ...
# 10                 13315                465                 14578  ...
# 13                 22025                798                 23248  ...
# 33                  4886                 94                  5113  ...
# 47                 10635                582                 10799  ...
# 2                   3705                122                  3809  ...
# 5                   7691                306                  7950  ...
# 9                  21019                499                 21628  ...
# 43                 14328                337                 15088  ...
# 4                  23956                713                 25427  ...
#
#     06-03-2021 confirmed  06-03-2021 deaths  06-04-2021 confirmed  \
# 50                 60549                720                 60628
# 48                162111               2807                162232
# 45                 24240                255                 24252
# 19                 67986                837                 68058
# 7                 108957               1668                109005
# 26                112129               1627                112260
# 24                318048               7324                318189
# 20                460194               9626                460339
# 34                110098               1546                110151
# 11                 36402                501                 36471
# 29                 98840               1354                 98877
# 8                  49041               1136                 49068
# 1                  70408                369                 70469
# 41                124242               2020                124261
# 39                151936               2715                151992
# 3                 341889               5842                342142
# 27                223517               2249                223558
# 17                459540               7077                460049
# 31                203330               4273                203472
# 40                593628               9739                593727
# 12                192630               2101                192795
# 38               1208879              27295               1209492
# 15                371765               6065                371862
# 49                674939               7923                675150
# 23                601881               7530                602134
# 44                406825               2308                407113
# 18                472617              10605                472981
# 30               1017044              26253               1017118
# 36                453400               7316                453552
# 32               2103768              53357               2104539
# 0                 545028              11188                545585
# 21                707523              17893                707723
# 16                315767               5081                316059
# 6                 347748               8245                347891
# 14                745690              13657                746135
# 28                325031               5599                325392
# 22                993952              20485                994506
# 42                863620              12472                863840
# 25                607774               9544                608463
# 37                202247               2683                202680
# 35               1103380              19980               1104001
# 46                676041              11216                676300
# 10               1125017              20900               1125512
# 13               1383647              25265               1384283
# 33               1003989              13130               1004669
# 47                438544               5821                439263
# 2                 882691              17653                883037
# 5                 545002               6603                545769
# 9                2329867              36973               2329867
# 43               2959171              51633               2961257
# 4                3792962              63345               3794129
#
#     06-04-2021 deaths  06-05-2021 confirmed  06-05-2021 deaths  \
# 50                720                 60628                720
# 48               2813                162232               2813
# 45                256                 24252                256
# 19                838                 68155                839
# 7                1674                109070               1677
# 26               1632                112260               1632
# 24               7325                318189               7325
# 20               9630                460471               9639
# 34               1546                110178               1547
# 11                501                 36535                502
# 29               1355                 98877               1355
# 8                1136                 49068               1136
# 1                 369                 70469                369
# 41               2022                124261               2022
# 39               2717                151992               2717
# 3                5845                342345               5846
# 27               2249                223558               2249
# 17               7086                460412               7091
# 31               4280                203472               4280
# 40               9744                593948               9752
# 12               2101                192795               2101
# 38              27325               1209894              27343
# 15               6067                371956               6068
# 49               7954                675150               7954
# 23               7538                602428               7554
# 44               2311                407419               2311
# 18              10615                472981              10615
# 30              26265               1017695              26273
# 36               7316                453552               7316
# 32              53416               2105375              53429
# 0               11198                545585              11198
# 21              17903                707940              17907
# 16               5085                316059               5085
# 6                8246                347891               8246
# 14              13661                746554              13685
# 28               5600                325392               5600
# 22              20511                994935              20588
# 42              12476                863840              12476
# 25               9554                608970               9558
# 37               2686                202995               2691
# 35              19980               1104380              19980
# 46              11222                676586              11229
# 10              20942               1125854              20986
# 13              25282               1384823              25314
# 33              13151               1004669              13151
# 47               5836                440057               5836
# 2               17673                883314              17698
# 5                6611                546500               6613
# 9               36973               2332867              36973
# 43              51676               2962395              51701
# 4               63401               3794927              63441
#
#     06-06-2021 confirmed  06-06-2021 deaths  cd_percentage  cc_percentage
# 50                 60628                720   1.281459e-76   2.214149e-82
# 48                162232               2813   4.601567e-83   2.567628e-89
# 45                 24252                256   1.787601e-77   2.864795e-83
# 19                 68233                839   1.085040e-81   8.071940e-88
# 7                 109126               1677   1.583347e-79   1.626007e-85
# 26                112260               1632   4.423846e-80   4.139162e-86
# 24                318189               7325   7.439089e-86   2.499569e-92
# 20                460575               9645   5.285282e-90   8.742246e-97
# 34                110199               1547   4.946675e-78   6.491171e-84
# 11                 36616                505   2.814071e-82   1.987518e-88
# 29                 98877               1355   1.339192e-81   9.849090e-88
# 8                  49068               1136   6.452003e-78   9.142065e-84
# 1                  70469                369   5.605617e-78   7.662710e-84
# 41                124261               2022   6.909908e-79   7.810815e-85
# 39                151992               2717   6.779615e-80   6.399721e-86
# 3                 342433               5846   6.590239e-86   2.183786e-92
# 27                223558               2249   2.176292e-83   1.125043e-89
# 17                460412               7091   3.647601e-88   8.164432e-95
# 31                203472               4280   6.406524e-84   3.055339e-90
# 40                594130               9754   6.458010e-89   1.254296e-95
# 12                192795               2101   5.690244e-83   3.184128e-89
# 38               1210224              27348   3.810496e-94  2.976487e-101
# 15                372024               6072   3.841006e-86   1.217407e-92
# 49                675150               7954   1.312007e-89   2.253366e-96
# 23                602686               7558   1.830545e-89   3.245859e-96
# 44                407642               2311   3.364103e-86   1.049329e-92
# 18                472981              10615   2.148224e-88   4.621034e-95
# 30               1017904              26279   5.350890e-92   6.024291e-99
# 36                453552               7316   1.965834e-87   4.968028e-94
# 32               2105882              53462   1.894290e-96  9.737498e-104
# 0                 545585              11198   1.175348e-88   2.397111e-95
# 21                708083              17911   1.296602e-90   1.881177e-97
# 16                316059               5085   9.961988e-86   3.419469e-92
# 6                 347891               8246   6.488141e-87   1.819809e-93
# 14                746554              13685   1.900404e-90   2.822849e-97
# 28                325392               5600   4.703151e-86   1.526920e-92
# 22                994935              20588   1.013424e-92   1.014757e-99
# 42                863840              12476   1.800026e-90   2.635789e-97
# 25                608578               9557   5.655962e-90   9.215525e-97
# 37                203252               2694   3.605138e-88   8.547565e-95
# 35               1104648              19980   1.242478e-93  1.062938e-100
# 46                676741              11236   6.211599e-92   7.277354e-99
# 10               1126134              20986   4.867684e-93  4.584619e-100
# 13               1385165              25352   5.032168e-94  3.971148e-101
# 33               1004669              13151   5.155571e-93  4.915647e-100
# 47                440057               5836   1.996253e-91   2.621512e-98
# 2                 883821              17700   7.543912e-91   1.036434e-97
# 5                 546874               6613   1.239672e-89   2.152681e-96
# 9                2332867              36973   5.248687e-97  2.443780e-104
# 43               2962934              51719   9.977314e-99  3.440942e-106
# 4                3795580              63557  1.678950e-100  4.249190e-108
#
# [51 rows x 849 columns]

# %%
rep_idx = new_df3[new_df3['party']=='republican'].index
dem_idx = new_df3[new_df3['party']!='republican'].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-8467cff59ebc> in <module>
# ----> 1 rep_idx = new_df3[new_df3['party']=='republican'].index
#       2 dem_idx = new_df3[new_df3['party']!='republican'].index
#
# NameError: name 'new_df3' is not defined

# %%
dens_idx = new_df3[new_df3['Density per square mile of land area']<=200].index
dens200_idx = new_df3[new_df3['Density per square mile of land area']>=200].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-0a3662f2ec61> in <module>
# ----> 1 dens_idx = new_df3[new_df3['Density per square mile of land area']<=200].index
#       2 dens200_idx = new_df3[new_df3['Density per square mile of land area']>=200].index
#
# NameError: name 'new_df3' is not defined

# %%
rep = confirmed_cases.T.pct_change().mean()[rep_idx]
dem = confirmed_cases.T.pct_change().mean()[dem_idx]
stats.ttest_ind(rep,dem)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-17bafba3d325> in <module>
# ----> 1 rep = confirmed_cases.T.pct_change().mean()[rep_idx]
#       2 dem = confirmed_cases.T.pct_change().mean()[dem_idx]
#       3 stats.ttest_ind(rep,dem)
#
# NameError: name 'rep_idx' is not defined

# %%
rep = confirmed_deaths.T.pct_change().mean()[rep_idx]
dem = confirmed_deaths.T.pct_change().mean()[dem_idx]
print(rep)
stats.ttest_ind(rep,dem)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-9cb51e54a3da> in <module>
# ----> 1 rep = confirmed_deaths.T.pct_change().mean()[rep_idx]
#       2 dem = confirmed_deaths.T.pct_change().mean()[dem_idx]
#       3 print(rep)
#       4 stats.ttest_ind(rep,dem)
#
# NameError: name 'rep_idx' is not defined

# %%
below = confirmed_deaths.T.pct_change().mean()[dens1_idx ]
over = confirmed_deaths.T.pct_change().mean()[dens100_idx]
print(len(below))
print(len(over))
stats.ttest_ind(below,over)
# Out:
# 25
# 26
# Ttest_indResult(statistic=4.292505369372853, pvalue=8.309748103503926e-05)

# %%
final_df = pd.read_csv('/home/aa1/Covid-cause-and-effect/Final_df.csv')
confirmed_cases=final_df.iloc[:,8::2]
confirmed_deaths=final_df.iloc[:,9::2]

# %%
ct = confirmed_cases.T
df1 = pd.Series(final_df['States'])
ct.columns=df1
ct
# Out:
# States                      Alabama        Alaska        Arizona  \
# 04-13-2020 confirmed    3870.000000    277.000000    3705.000000
# 04-14-2020 confirmed    4041.000000    285.000000    3809.000000
# 04-15-2020 confirmed    4307.000000    293.000000    3964.000000
# 04-16-2020 confirmed    4465.000000    300.000000    4237.000000
# 04-17-2020 confirmed    4557.000000    309.000000    4511.000000
# ...                             ...           ...            ...
# 06-03-2021 confirmed  545028.000000  70408.000000  882691.000000
# 06-04-2021 confirmed  545585.000000  70469.000000  883037.000000
# 06-05-2021 confirmed  545585.000000  70469.000000  883314.000000
# 06-06-2021 confirmed  545585.000000  70469.000000  883821.000000
# cd_percentage              0.002284      0.000504       0.002432
#
# States                     Arkansas    California       Colorado  \
# 04-13-2020 confirmed    1410.000000  2.395600e+04    7691.000000
# 04-14-2020 confirmed    1498.000000  2.542700e+04    7950.000000
# 04-15-2020 confirmed    1569.000000  2.671900e+04    7956.000000
# 04-16-2020 confirmed    1620.000000  2.768700e+04    8286.000000
# 04-17-2020 confirmed    1695.000000  2.947000e+04    8691.000000
# ...                             ...           ...            ...
# 06-03-2021 confirmed  341889.000000  3.792962e+06  545002.000000
# 06-04-2021 confirmed  342142.000000  3.794129e+06  545769.000000
# 06-05-2021 confirmed  342345.000000  3.794927e+06  546500.000000
# 06-06-2021 confirmed  342433.000000  3.795580e+06  546874.000000
# cd_percentage              0.001937  1.608540e-03       0.001148
#
# States                  Connecticut       Delaware  District of Columbia  \
# 04-13-2020 confirmed   13381.000000    1758.000000            1955.00000
# 04-14-2020 confirmed   13989.000000    1926.000000            2058.00000
# 04-15-2020 confirmed   14755.000000    2014.000000            2197.00000
# 04-16-2020 confirmed   15884.000000    2070.000000            2350.00000
# 04-17-2020 confirmed   16809.000000    2317.000000            2476.00000
# ...                             ...            ...                   ...
# 06-03-2021 confirmed  347748.000000  108957.000000           49041.00000
# 06-04-2021 confirmed  347891.000000  109005.000000           49068.00000
# 06-05-2021 confirmed  347891.000000  109070.000000           49068.00000
# 06-06-2021 confirmed  347891.000000  109126.000000           49068.00000
# cd_percentage              0.002313       0.001722               0.00161
#
# States                     Florida  ...   South Dakota      Tennessee  \
# 04-13-2020 confirmed  2.101900e+04  ...     868.000000    5610.000000
# 04-14-2020 confirmed  2.162800e+04  ...     988.000000    5827.000000
# 04-15-2020 confirmed  2.251100e+04  ...    1168.000000    5827.000000
# 04-16-2020 confirmed  2.334300e+04  ...    1311.000000    6375.000000
# 04-17-2020 confirmed  2.475900e+04  ...    1411.000000    6263.000000
# ...                            ...  ...            ...            ...
# 06-03-2021 confirmed  2.329867e+06  ...  124242.000000  863620.000000
# 06-04-2021 confirmed  2.329867e+06  ...  124261.000000  863840.000000
# 06-05-2021 confirmed  2.332867e+06  ...  124261.000000  863840.000000
# 06-06-2021 confirmed  2.332867e+06  ...  124261.000000  863840.000000
# cd_percentage         1.721457e-03  ...       0.002286       0.001827
#
# States                       Texas           Utah      Vermont       Virginia  \
# 04-13-2020 confirmed  1.432800e+04    2363.000000    748.00000    5747.000000
# 04-14-2020 confirmed  1.508800e+04    2417.000000    752.00000    6182.000000
# 04-15-2020 confirmed  1.604400e+04    2548.000000    759.00000    6500.000000
# 04-16-2020 confirmed  1.698500e+04    2683.000000    774.00000    6889.000000
# 04-17-2020 confirmed  1.792500e+04    2793.000000    779.00000    7491.000000
# ...                            ...            ...          ...            ...
# 06-03-2021 confirmed  2.959171e+06  406825.000000  24240.00000  676041.000000
# 06-04-2021 confirmed  2.961257e+06  407113.000000  24252.00000  676300.000000
# 06-05-2021 confirmed  2.962395e+06  407419.000000  24252.00000  676586.000000
# 06-06-2021 confirmed  2.962934e+06  407642.000000  24252.00000  676741.000000
# cd_percentage         1.783667e-03       0.000721      0.00041       0.001316
#
# States                   Washington  West Virginia      Wisconsin  \
# 04-13-2020 confirmed   10635.000000      611.00000    3428.000000
# 04-14-2020 confirmed   10799.000000      640.00000    3555.000000
# 04-15-2020 confirmed   10942.000000      702.00000    3721.000000
# 04-16-2020 confirmed   11057.000000      728.00000    3875.000000
# 04-17-2020 confirmed   11517.000000      775.00000    4053.000000
# ...                             ...            ...            ...
# 06-03-2021 confirmed  438544.000000   162111.00000  674939.000000
# 06-04-2021 confirmed  439263.000000   162232.00000  675150.000000
# 06-05-2021 confirmed  440057.000000   162232.00000  675150.000000
# 06-06-2021 confirmed  440057.000000   162232.00000  675150.000000
# cd_percentage              0.000766        0.00157       0.001366
#
# States                     Wyoming
# 04-13-2020 confirmed    275.000000
# 04-14-2020 confirmed    282.000000
# 04-15-2020 confirmed    287.000000
# 04-16-2020 confirmed    296.000000
# 04-17-2020 confirmed    305.000000
# ...                            ...
# 06-03-2021 confirmed  60549.000000
# 06-04-2021 confirmed  60628.000000
# 06-05-2021 confirmed  60628.000000
# 06-06-2021 confirmed  60628.000000
# cd_percentage             0.001244
#
# [421 rows x 51 columns]

# %%
ct.drop(index='cd_percentage',axis=0, inplace=True)

# %%
fig = px.line(ct, title="Covid Cases Over Time by State")
fig.update_traces(mode="markers+lines", hovertemplate=None)
fig.update_layout(hovermode="x")
fig.update_layout(legend_orientation='h')
fig.update_yaxes(type="log")
fig.update_layout(
    autosize=False,
    width=1500,
    height=850,
    paper_bgcolor="LightSteelBlue")
fig.write_html("/home/aa1/Covid-cause-and-effect/SuperGraph5000.html")
